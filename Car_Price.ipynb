# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('car_data.csv')
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
data.shape
# Out:
# (301, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
data.describe().T
# Out:
#                count          mean           std      min      25%      50%  \
# Year           301.0   2013.627907      2.891554  2003.00   2012.0   2014.0
# Selling_Price  301.0      4.661296      5.082812     0.10      0.9      3.6
# Present_Price  301.0      7.628472      8.644115     0.32      1.2      6.4
# Kms_Driven     301.0  36947.205980  38886.883882   500.00  15000.0  32000.0
# Owner          301.0      0.043189      0.247915     0.00      0.0      0.0
#
#                    75%       max
# Year            2016.0    2018.0
# Selling_Price      6.0      35.0
# Present_Price      9.9      92.6
# Kms_Driven     48767.0  500000.0
# Owner              0.0       3.0

# %%
data = data.drop('Car_Name', axis=1)
data.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %%
data['Years_old'] = 2022 - data.Year     
data.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Years_old
# 0       Manual      0          8
# 1       Manual      0          9
# 2       Manual      0          5
# 3       Manual      0         11
# 4       Manual      0          8

# %%
data.drop('Year', axis=1, inplace=True)
data.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Years_old
# 0       Manual      0          8
# 1       Manual      0          9
# 2       Manual      0          5
# 3       Manual      0         11
# 4       Manual      0          8

# %%
data = pd.get_dummies(data,drop_first=True)

# %%
data.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  Years_old  \
# 0           3.35           5.59       27000      0          8
# 1           4.75           9.54       43000      0          9
# 2           7.25           9.85        6900      0          5
# 3           2.85           4.15        5200      0         11
# 4           4.60           6.87       42450      0          8
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                 0                 1                       0
# 1                 1                 0                       0
# 2                 0                 1                       0
# 3                 0                 1                       0
# 4                 1                 0                       0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
sns.pairplot(data);

# %%
plt.figure(figsize=(15,15))
sns.heatmap(
    data.corr(), 
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
);

# %%
data.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  Years_old  \
# 0           3.35           5.59       27000      0          8
# 1           4.75           9.54       43000      0          9
# 2           7.25           9.85        6900      0          5
# 3           2.85           4.15        5200      0         11
# 4           4.60           6.87       42450      0          8
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                 0                 1                       0
# 1                 1                 0                       0
# 2                 0                 1                       0
# 3                 0                 1                       0
# 4                 1                 0                       0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
X = data.drop('Selling_Price', axis = 1)
y = data['Selling_Price']
print(X.shape)
print(y.shape)
# Out:
# (301, 8)
# (301,)

# %%
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()
model.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
model.feature_importances_
# Out:
# array([0.37646152, 0.04455497, 0.0009027 , 0.07102622, 0.23562337,
#        0.01244957, 0.1224794 , 0.13650225])

# %%
pd.Series(model.feature_importances_, index=X.columns).plot(kind='bar',alpha=0.75, rot=90);

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
model.score(X_test,y_test)
# Out:
# 0.9144342972228519

# %%
predictions=model.predict(X_test)
plt.scatter(y_test,predictions)

# %%
import pickle
with open('RF_price_predicting_model.pkl', 'wb') as file:
  # dump information to that file
  pickle.dump(model, open('RF_price_predicting_model.pkl', 'wb'))

# %%
# Out:
# Collecting streamlit
#   Downloading streamlit-1.17.0-py2.py3-none-any.whl (9.3 MB)
#      ---------------------------------------- 9.3/9.3 MB 3.7 MB/s eta 0:00:00
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.8.0-py2.py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: pillow>=6.2.0 in d:\new folder (7)\lib\site-packages (from streamlit) (9.4.0)
# Collecting altair>=3.2.0
#   Downloading altair-4.2.2-py3-none-any.whl (813 kB)
#      -------------------------------------- 813.6/813.6 kB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.21.0 in d:\new folder (7)\lib\site-packages (from streamlit) (1.5.2)
# Collecting watchdog
#   Downloading watchdog-2.2.1-py3-none-win_amd64.whl (78 kB)
#      ---------------------------------------- 79.0/79.0 kB 4.6 MB/s eta 0:00:00
# Collecting rich>=10.11.0
#   Downloading rich-13.3.1-py3-none-any.whl (239 kB)
#      ------------------------------------- 239.0/239.0 kB 14.3 MB/s eta 0:00:00
# Collecting tzlocal>=1.1
#   Downloading tzlocal-4.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: tornado>=5.0 in c:\users\jibra\appdata\roaming\python\python310\site-packages (from streamlit) (6.2)
# Collecting semver
#   Downloading semver-2.13.0-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: cachetools>=4.0 in d:\new folder (7)\lib\site-packages (from streamlit) (5.3.0)
# Collecting pympler>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      -------------------------------------- 164.8/164.8 kB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.4 in d:\new folder (7)\lib\site-packages (from streamlit) (2.28.1)
# Requirement already satisfied: numpy in d:\new folder (7)\lib\site-packages (from streamlit) (1.24.1)
# Requirement already satisfied: packaging>=14.1 in c:\users\jibra\appdata\roaming\python\python310\site-packages (from streamlit) (22.0)
# Collecting protobuf<4,>=3.12
#   Downloading protobuf-3.20.3-cp310-cp310-win_amd64.whl (904 kB)
#      ------------------------------------- 904.0/904.0 kB 19.0 MB/s eta 0:00:00
# Collecting importlib-metadata>=1.4
#   Downloading importlib_metadata-6.0.0-py3-none-any.whl (21 kB)
# Requirement already satisfied: python-dateutil in c:\users\jibra\appdata\roaming\python\python310\site-packages (from streamlit) (2.8.2)
# Collecting pyarrow>=4.0
#   Downloading pyarrow-11.0.0-cp310-cp310-win_amd64.whl (20.6 MB)
#      ---------------------------------------- 20.6/20.6 MB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.10.0.0 in d:\new folder (7)\lib\site-packages (from streamlit) (4.4.0)
# Requirement already satisfied: click>=7.0 in d:\new folder (7)\lib\site-packages (from streamlit) (8.1.3)
# Collecting blinker>=1.0.0
#   Downloading blinker-1.5-py2.py3-none-any.whl (12 kB)
# Collecting validators>=0.2
#   Downloading validators-0.20.0.tar.gz (30 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting toml
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting gitpython!=3.1.19
#   Downloading GitPython-3.1.30-py3-none-any.whl (184 kB)
#      -------------------------------------- 184.0/184.0 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: entrypoints in c:\users\jibra\appdata\roaming\python\python310\site-packages (from altair>=3.2.0->streamlit) (0.4)
# Collecting jsonschema>=3.0
#   Downloading jsonschema-4.17.3-py3-none-any.whl (90 kB)
#      ---------------------------------------- 90.4/90.4 kB 5.0 MB/s eta 0:00:00
# Collecting toolz
#   Downloading toolz-0.12.0-py3-none-any.whl (55 kB)
#      ---------------------------------------- 55.8/55.8 kB 3.0 MB/s eta 0:00:00
# Collecting jinja2
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      -------------------------------------- 133.1/133.1 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\jibra\appdata\roaming\python\python310\site-packages (from click>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ---------------------------------------- 62.7/62.7 kB 3.3 MB/s eta 0:00:00
# Collecting zipp>=0.5
#   Downloading zipp-3.12.1-py3-none-any.whl (6.7 kB)
# Requirement already satisfied: pytz>=2020.1 in d:\new folder (7)\lib\site-packages (from pandas>=0.21.0->streamlit) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\jibra\appdata\roaming\python\python310\site-packages (from python-dateutil->streamlit) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\new folder (7)\lib\site-packages (from requests>=2.4->streamlit) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in d:\new folder (7)\lib\site-packages (from requests>=2.4->streamlit) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in d:\new folder (7)\lib\site-packages (from requests>=2.4->streamlit) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\new folder (7)\lib\site-packages (from requests>=2.4->streamlit) (2.1.1)
# Collecting markdown-it-py<3.0.0,>=2.1.0
#   Downloading markdown_it_py-2.1.0-py3-none-any.whl (84 kB)
#      ---------------------------------------- 84.5/84.5 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.14.0 in c:\users\jibra\appdata\roaming\python\python310\site-packages (from rich>=10.11.0->streamlit) (2.14.0)
# Collecting pytz-deprecation-shim
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Collecting tzdata
#   Downloading tzdata-2022.7-py2.py3-none-any.whl (340 kB)
#      -------------------------------------- 340.1/340.1 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: decorator>=3.4.0 in c:\users\jibra\appdata\roaming\python\python310\site-packages (from validators>=0.2->streamlit) (5.1.1)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.2-cp310-cp310-win_amd64.whl (16 kB)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Downloading pyrsistent-0.19.3-cp310-cp310-win_amd64.whl (62 kB)
#      ---------------------------------------- 62.7/62.7 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.4.0 in d:\new folder (7)\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (22.2.0)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: zipp, watchdog, validators, tzdata, toolz, toml, smmap, semver, pyrsistent, pympler, pyarrow, protobuf, mdurl, MarkupSafe, blinker, pytz-deprecation-shim, markdown-it-py, jsonschema, jinja2, importlib-metadata, gitdb, tzlocal, rich, pydeck, gitpython, altair, streamlit
#   Running setup.py install for validators: started
#   Running setup.py install for validators: finished with status 'done'
# Successfully installed MarkupSafe-2.1.2 altair-4.2.2 blinker-1.5 gitdb-4.0.10 gitpython-3.1.30 importlib-metadata-6.0.0 jinja2-3.1.2 jsonschema-4.17.3 markdown-it-py-2.1.0 mdurl-0.1.2 protobuf-3.20.3 pyarrow-11.0.0 pydeck-0.8.0 pympler-1.0.1 pyrsistent-0.19.3 pytz-deprecation-shim-0.1.0.post0 rich-13.3.1 semver-2.13.0 smmap-5.0.0 streamlit-1.17.0 toml-0.10.2 toolz-0.12.0 tzdata-2022.7 tzlocal-4.2 validators-0.20.0 watchdog-2.2.1 zipp-3.12.1
# Note: you may need to restart the kernel to use updated packages.
#   DEPRECATION: validators is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
